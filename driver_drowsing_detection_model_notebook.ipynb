# %%
# Core numerical & data handling
# !pip install numpy pandas

# Visualization
# !pip install matplotlib

# Computer vision
# !pip install opencv-python

# Machine Learning utilities
# !pip install scikit-learn

# Deep Learning (USED IN YOUR NOTEBOOK)
# !pip install tensorflow
# Out:
# Requirement already satisfied: numpy in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (1.21.6)
# Requirement already satisfied: pandas in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (3.5.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: typing-extensions in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from kiwisolver>=1.0.1->matplotlib) (4.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: opencv-python in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy<2.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from opencv-python) (1.21.6)
# Requirement already satisfied: scikit-learn in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: tensorflow in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.8.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (25.2.10)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.31.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.17.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.7.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.6)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.62.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (18.1.1)
# Requirement already satisfied: packaging in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.0)
# Requirement already satisfied: setuptools in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (65.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.38.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.31.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (6.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.10)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\mayank manchanda\anaconda3\envs\tf37\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # **Import all the required dependancies**

# %%
import os
import matplotlib.pyplot as plt
import cv2
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D,Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %% [markdown]
# # **Visualization of the dataset with the labels**

# %%
train_images_path = 'C:/Users/Mayank Manchanda/.cache/kagglehub/datasets/zeyad1mashhour/driver-inattention-detection-dataset/versions/1/train'
annotation_file_path = 'C:/Users/Mayank Manchanda/.cache/kagglehub/datasets/zeyad1mashhour/driver-inattention-detection-dataset/versions/1/train/_annotations.txt'

class_names = {
    0: 'DangerousDriving',
    1: 'Distracted',
    2: 'Drinking',
    3: 'SafeDriving',
    4: 'SleepyDriving',
    5: 'Yawn'
}

annotations = {}

with open(annotation_file_path, 'r') as f:
    for line in f:
        parts = line.strip().split()
        
        if len(parts) < 2:
            print(f'skipping due to the incorrect format: {line}')
            continue
            
        image_name = parts[0]
        
        bbox_and_class = parts[1].split(',')
        
        if len(bbox_and_class) <5:
            print(f"Skipping the line due to missing bouding box or class info: {line}")
            continue
            
        class_id = int(bbox_and_class[-1])
        
        annotations[image_name] = class_id
# Out:
# skipping due to the incorrect format: gA_4_s2_ir_face_mp4-440_jpg.rf.f0ab9d03d718ac287cac6fca394783d0.jpg
#
# skipping due to the incorrect format: gA_4_s2_ir_face_mp4-440_jpg.rf.fa7c39ef44d869bdab6c298c89442f19.jpg
#
# skipping due to the incorrect format: gB_9_s1_2019-03-07T16-36-24-01-00_ir_face_mp4-401_jpg.rf.4a274f58e714facd11a3693a3325c3d5.jpg
#
# skipping due to the incorrect format: gB_9_s1_2019-03-07T16-36-24-01-00_ir_face_mp4-401_jpg.rf.c507475339c83c2de42f2400987923d2.jpg

# %%
print(type(parts))
print(type(annotations))
# Out:
# <class 'list'>
# <class 'dict'>

# %%
def load_image_and_label(image_name):
    
    img_path = os.path.join(train_images_path, image_name)
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    if image_name in annotations:
        class_id = annotations[image_name]
        return img, class_names[class_id]
    else:
        print(f'Warning: No label found for {image_name}')
        return img, "No label"
    
plt.figure(figsize = (10,10))
image_files = os.listdir(train_images_path)[:9]

for i, image_file in enumerate(image_files):
    img, label = load_image_and_label(image_file)

    ax = plt.subplot(3,3,i+1)
    plt.imshow(img)
    plt.title(f'label: {label}')
    plt.axis('off')

plt.show()

# %% [markdown]
# # **Data preprocessing**

# %%
def read_annotations(file_path):
    annotations = []
    with open(file_path,'r') as file:
        for line in file:
            parts = line.strip().split()
            if len(parts) < 2:
                continue
            image_name = parts[0]
            try:
                bbox = list(map(int,parts[1].split(',')))
                if len(bbox) !=5:
                    continue
                annotations.append([image_name] + bbox)
            except ValueError:
                continue
    return pd.DataFrame(annotations,columns = ['image_name','x_min','y_min','x_max','y_max','class_id'])

# %%
target_size = (224,224)
def preprocess_image(image_path,target_size):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    image = cv2.resize(image,target_size)
    return image

# %%
def one_hot_encode_labels(labels,num_classes):
    encoder = OneHotEncoder(sparse = False)
    labels = np.array(labels).reshape(-1,1)
    one_hot_labels = encoder.fit_transform(labels)
    return one_hot_labels

# %%
train_folder = 'C:/Users/Mayank Manchanda/.cache/kagglehub/datasets/zeyad1mashhour/driver-inattention-detection-dataset/versions/1/train'
test_folder = 'C:/Users/Mayank Manchanda/.cache/kagglehub/datasets/zeyad1mashhour/driver-inattention-detection-dataset/versions/1/test'
valid_folder = 'C:/Users/Mayank Manchanda/.cache/kagglehub/datasets/zeyad1mashhour/driver-inattention-detection-dataset/versions/1/valid'

train_annotations = read_annotations('C:/Users/Mayank Manchanda/.cache/kagglehub/datasets/zeyad1mashhour/driver-inattention-detection-dataset/versions/1/train/_annotations.txt')
test_annotations = read_annotations('C:/Users/Mayank Manchanda/.cache/kagglehub/datasets/zeyad1mashhour/driver-inattention-detection-dataset/versions/1/test/_annotations.txt')
valid_annotations = read_annotations('C:/Users/Mayank Manchanda/.cache/kagglehub/datasets/zeyad1mashhour/driver-inattention-detection-dataset/versions/1/valid/_annotations.txt')

# %%
def preprocess_dataset(annotations,folder_path,num_classes):
    images = []
    labels = []
#     print(annotations.head())
#     print(annotations.columns)
    
    for _, row in annotations.iterrows():
        image_path = os.path.join(folder_path,row['image_name'])
        image = preprocess_image(image_path,target_size)
        images.append(image)
        labels.append(row['class_id'])
    images = np.array(images)
    one_hot_labels = one_hot_encode_labels(labels, num_classes)
    return images,one_hot_labels

num_classes = 6

train_images, train_labels = preprocess_dataset(train_annotations,train_folder,num_classes)
test_images, test_labels = preprocess_dataset(test_annotations,test_folder,num_classes)
valid_images, valid_labels = preprocess_dataset(valid_annotations,valid_folder,num_classes)

# %% [markdown]
# # **Shape of the dataset after preprocessing steps**

# %%
print(f'Train images shape: {train_images.shape}')
print(f'Train labels shape: {train_labels.shape}')
print(f'Test images shape: {test_images.shape}')
print(f'Test labels shape: {test_labels.shape}')
print(f'Valid images shape: {valid_images.shape}')
print(f'Valid labels shape: {valid_labels.shape}')
# Out:
# Train images shape: (11948, 224, 224, 3)
# Train labels shape: (11948, 6)
# Test images shape: (985, 224, 224, 3)
# Test labels shape: (985, 6)
# Valid images shape: (1922, 224, 224, 3)
# Valid labels shape: (1922, 6)

# %%
print(type(train_images))
print(type(train_labels))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# # **Assigning the data to Train and Validation**

# %%
(X_train, y_train), (X_val, y_val) = (train_images, train_labels), (valid_images, valid_labels)

# %% [markdown]
# # **Neural netowork (CNN model)**

# %% [markdown]
# # **Classical CNN model**

# %%
model = Sequential([
    Conv2D(32,(3,3),activation = 'relu',input_shape=(224,224,3)),
    MaxPooling2D((2,2)),
    Conv2D(64,(3,3), activation = 'relu'),
    MaxPooling2D((2,2)),
    Conv2D(128,(3,3), activation = 'relu'),
    MaxPooling2D((2,2)),
    Conv2D(256,(3,3), activation = 'relu'),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(512, activation = 'relu'),
    Dropout(0.5),
    Dense(6,activation = 'softmax')
]) 

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dense (Dense)               (None, 512)               18874880
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 6)                 3078
#
# =================================================================
# Total params: 19,266,374
# Trainable params: 19,266,374
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/20
# 374/374 [==============================] - 541s 1s/step - loss: 3.3550 - accuracy: 0.6510 - val_loss: 0.6680 - val_accuracy: 0.7591
# Epoch 2/20
# 374/374 [==============================] - 2375s 6s/step - loss: 0.5832 - accuracy: 0.7929 - val_loss: 0.4510 - val_accuracy: 0.8460
# Epoch 3/20
# 374/374 [==============================] - 2689s 7s/step - loss: 0.4567 - accuracy: 0.8412 - val_loss: 0.4821 - val_accuracy: 0.8309
# Epoch 4/20
# 374/374 [==============================] - 2969s 8s/step - loss: 0.4012 - accuracy: 0.8599 - val_loss: 0.3830 - val_accuracy: 0.8845
# Epoch 5/20
# 374/374 [==============================] - 2982s 8s/step - loss: 0.3474 - accuracy: 0.8791 - val_loss: 0.3614 - val_accuracy: 0.8939
# Epoch 6/20
# 374/374 [==============================] - 3028s 8s/step - loss: 0.3224 - accuracy: 0.8884 - val_loss: 0.3712 - val_accuracy: 0.8861
# Epoch 7/20
# 374/374 [==============================] - 2749s 7s/step - loss: 0.3182 - accuracy: 0.8897 - val_loss: 0.3888 - val_accuracy: 0.8824
# Epoch 8/20
# 374/374 [==============================] - 1217s 3s/step - loss: 0.2707 - accuracy: 0.9052 - val_loss: 0.3785 - val_accuracy: 0.8918
# Epoch 9/20
# 374/374 [==============================] - 830s 2s/step - loss: 0.2478 - accuracy: 0.9128 - val_loss: 0.3482 - val_accuracy: 0.9011
# Epoch 10/20
# 374/374 [==============================] - 823s 2s/step - loss: 0.2377 - accuracy: 0.9163 - val_loss: 0.4008 - val_accuracy: 0.8965
# Epoch 11/20
# 374/374 [==============================] - 823s 2s/step - loss: 0.2385 - accuracy: 0.9160 - val_loss: 0.3649 - val_accuracy: 0.9058
# Epoch 12/20
# 374/374 [==============================] - 832s 2s/step - loss: 0.2143 - accuracy: 0.9233 - val_loss: 0.3602 - val_accuracy: 0.8991
# Epoch 13/20
# 374/374 [==============================] - 822s 2s/step - loss: 0.2129 - accuracy: 0.9247 - val_loss: 0.4149 - val_accuracy: 0.8933
# Epoch 14/20
# 374/374 [==============================] - 806s 2s/step - loss: 0.1990 - accuracy: 0.9281 - val_loss: 0.3683 - val_accuracy: 0.9022
# Epoch 15/20
# 374/374 [==============================] - 833s 2s/step - loss: 0.1863 - accuracy: 0.9354 - val_loss: 0.4159 - val_accuracy: 0.8996
# Epoch 16/20
# 374/374 [==============================] - 811s 2s/step - loss: 0.1842 - accuracy: 0.9343 - val_loss: 0.3607 - val_accuracy: 0.9095
# Epoch 17/20
# 374/374 [==============================] - 830s 2s/step - loss: 0.1778 - accuracy: 0.9384 - val_loss: 0.4114 - val_accuracy: 0.8996
# Epoch 18/20
# 374/374 [==============================] - 814s 2s/step - loss: 0.1767 - accuracy: 0.9381 - val_loss: 0.4045 - val_accuracy: 0.9037
# Epoch 19/20
# 374/374 [==============================] - 808s 2s/step - loss: 0.1889 - accuracy: 0.9377 - val_loss: 0.3555 - val_accuracy: 0.9121
# Epoch 20/20
# 374/374 [==============================] - 614s 2s/step - loss: 0.1576 - accuracy: 0.9465 - val_loss: 0.4253 - val_accuracy: 0.9063

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Plot the first 16 images with actual label and predicted label**

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to plot 16 images in a grid with predicted and actual labels
def plot_images_grid_with_predictions(images, actual_labels, predicted_labels, class_names, grid_size=(4, 4)):
    fig, axes = plt.subplots(grid_size[0], grid_size[1], figsize=(12, 12))
    axes = axes.flatten()
    
    for i, ax in enumerate(axes):
        if i < len(images):
            ax.imshow(images[i])
            actual_label = class_names[np.argmax(actual_labels[i])]
            predicted_label = class_names[np.argmax(predicted_labels[i])]
            ax.set_title(f'Actual: {actual_label}\nPredicted: {predicted_label}')
            ax.axis('off')
        else:
            ax.axis('off')
    
    plt.tight_layout()
    plt.show()

class_names = ['DangerousDriving', 'Distracted', 'Drinking', 'SafeDriving', 'SleepyDriving', 'Yawn']

# Select 16 random test images
indices = np.random.choice(len(test_images), 16, replace=False)
sample_images = test_images[indices]
sample_actual_labels = test_labels[indices]

# Predict the labels
sample_predicted_labels = model.predict(sample_images)

# Plot the images in a grid with predictions
plot_images_grid_with_predictions(sample_images, sample_actual_labels, sample_predicted_labels, class_names)
# Out:
# 1/1 [==============================] - 1s 683ms/step

# %% [markdown]
# # **Accuracy of the test dataset**

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_accuracy:.2f}')
# Out:
# 31/31 [==============================] - 10s 301ms/step - loss: 0.4215 - accuracy: 0.8944
# Test accuracy: 0.89

# %%
# **Save the model in h5 version**

# %%
# Save the model
model.save('driving_behavior_model.h5')
